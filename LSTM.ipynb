# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita1204/python/blob/main/LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# LSTM is an improved version of RNN that solves the vanishing gradient problem.
# it has 3 gates : forget gate, input gate , output gate
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
import numpy as np

X = np.random.rand(100,10,1)
y = np.random.randint(0,2,100)

model = Sequential([
    LSTM(64,input_shape=(10,1)),
    Dense(1,activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.fit(X,y,epochs=5)
