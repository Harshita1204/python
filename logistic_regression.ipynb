# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita1204/python/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# dataset
x = np.array([[30],[35],[40],[45],[50],[55],[60],[65]])
y = np.array([0,0,0,0,1,1,1,1]) # 0 = fail , 1 = pass

#model
model = LogisticRegression()

# train
model.fit(x,y)

#predict
#predicted_y = model.predict(x)
#print(predicted_y)
marks=[[40]]
prediction = model.predict(marks)

print("prediction(0=fail,1=pass):",prediction[0])
# Out:
# prediction(0=fail,1=pass): 0
