# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita1204/python/blob/main/numpy1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
x=[4,5,7,3,9,2]
print (np.array(x))
# Out:
# [4 5 7 3 9 2]

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git clone https://github.com/Harshita1204/python
# Out:
# Cloning into 'python'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 12 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (12/12), 7.41 KiB | 3.71 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd python
# Out:
# /content/python

# %%
# !git add .

# %%
# !git commit -m "using numpy"
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@1bf3621666d2.(none)')

# %%
# !git push origin main
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# ### Step 1: Set up Git Configuration
#
# First, you need to configure your Git username and email. This is important for commit attribution.

# %%
# !git config --global user.email "your_email@example.com"
# !git config --global user.name "Your Name"

# %% [markdown]
# ### Step 2: Authenticate with GitHub
#
# You'll need a GitHub Personal Access Token (PAT) to authenticate. It's recommended to create a PAT with appropriate permissions (e.g., `repo` scope) from your GitHub settings.
#
# Store your PAT securely, for example, in Colab's Secrets manager under the "🔑" icon in the left panel. Name it `GH_TOKEN`.
#
# Then, use it to authenticate. You can use `ghp_` prefix if you are creating a new token. Note that PATs are sensitive, avoid hardcoding them directly in your notebook.

# %%
from google.colab import userdata

# Retrieve your GitHub Personal Access Token from Colab Secrets
GH_TOKEN = userdata.get('GH_TOKEN')

# This step is typically handled when you add the remote URL, or when Git prompts for credentials.
# For HTTPS, you can include the token in the URL for one-time use or use a credential helper.
# For example, when adding a remote:
# !git remote add origin https://<YOUR_GH_USERNAME>:$GH_TOKEN@github.com/<YOUR_GH_USERNAME>/<YOUR_REPO_NAME>.git

# Alternatively, you can use a credential helper:
# !git config --global credential.helper store

# %% [markdown]
# ### Step 3: Initialize a Git Repository (if not already done)
#
# If your Colab environment is not already a Git repository, you need to initialize one. You'll typically do this in the root of your project directory. Colab notebooks usually run in `/content/`.

# %%
# Change to the /content/ directory first
# %cd /content/

# Clone your existing 'python' repository
# Replace <YOUR_GH_USERNAME> with your actual GitHub username
# !git clone https://github.com/<YOUR_GH_USERNAME>/python.git

# Change into the cloned repository's directory
# %cd python

# After running this, make sure to save your current Colab notebook
# (File -> Save a copy in GitHub) or download and upload it into this 'python' directory
# so that it resides within the cloned repository.

# %% [markdown]
# ### Step 4: Add your files to the repository
#
# Add the files you want to track and commit. You can add specific files or all files.

# %%
# To add your specific notebook file (e.g., 'Your_Notebook_Name.ipynb')
# Ensure you have saved your current Colab notebook into this directory first.
# Replace 'Your_Notebook_Name.ipynb' with the actual name of your notebook file.
# !git add "Your_Notebook_Name.ipynb"

# If you want to add all changed files in the current repository directory (e.g., after cloning):
# !git add .

# %% [markdown]
# ### Step 5: Commit your changes
#
# Commit the added files with a descriptive message.

# %%
# !git commit -m "Initial commit from Colab"

# %% [markdown]
# ### Step 6: Add a Remote Repository
#
# Link your local repository to your GitHub repository. Replace `<YOUR_GH_USERNAME>` and `<YOUR_REPO_NAME>` with your actual GitHub username and repository name.

# %%
# Check if a remote named 'origin' already exists
# (This should already be set if you cloned the repository in Step 3)
# !git remote -v

# If 'origin' does not exist (e.g., if you initialized a new repo instead of cloning),
# you would add it using a command like this:
# !git remote add origin https://{YOUR_GH_USERNAME}:{GH_TOKEN}@github.com/{YOUR_GH_USERNAME}/{YOUR_REPO_NAME}.git

# Since you cloned, 'origin' should already be configured to your GitHub repository.
# You usually don't need to run `git remote add origin` after cloning.

# %% [markdown]
# ### Step 7: Push your code to GitHub
#
# Finally, push your committed changes to the remote repository. The `-u` flag sets the upstream branch, so you can just use `git push` later.

# %%
# !git push -u origin main

# %% [markdown]
# ### Important Notes:
#
# *   **Existing Repository:** If you're working with an existing GitHub repository, you'd typically clone it first (`!git clone https://github.com/<YOUR_GH_USERNAME>/<YOUR_REPO_NAME>.git`), then `cd` into the cloned directory before making changes and pushing.
# *   **Branch Name:** GitHub's default branch is now typically `main`, but some older repositories might still use `master`. Adjust `main` in `git push -u origin main` accordingly.
# *   **Security:** Be extremely careful with your Personal Access Token. Never share it or expose it in publicly accessible notebooks. Using Colab Secrets is a good practice.
