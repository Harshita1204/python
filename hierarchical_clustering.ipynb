# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita1204/python/blob/main/hierarchical_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import AgglomerativeClustering
X = [[1,2],[2,3],[8,8],[9,10]]
model = AgglomerativeClustering(n_clusters=2)
labels = model.fit_predict(X)
print(labels)
# Out:
# [1 1 0 0]
