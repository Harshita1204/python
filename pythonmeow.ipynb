# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita1204/python/blob/main/pythonmeow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Harshu")
# Out:
# Harshu

# %%
a = 10
b=20
print(a+b)
# Out:
# 30

# %%
# Write a program to calculate the sum of digiots of an integet betwweenn 1 to 10000

# %%
word = "Harshita"
for index, char in enumerate(word):
    print(f"Character at index {index}: {char}")
# Out:
# Character at index 0: H
# Character at index 1: a
# Character at index 2: r
# Character at index 3: s
# Character at index 4: h
# Character at index 5: i
# Character at index 6: t
# Character at index 7: a

# %%
print("hello me")
# Out:
# hello me
