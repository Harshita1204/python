# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita1204/python/blob/main/predictSalary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np;
import pandas as pd;
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

data={
    'experience':[1,2,3,4,5,6],
    'salary':[25000,30000,35000,40000,45000,50000]
}
df=pd.DataFrame(data)
x=df[['experience']]
y=df['salary']
model=LinearRegression()
model.fit(x,y)
new_experience=[[7]]
new_experience1=[[10]]
predicted_salary=model.predict(new_experience)
predicted_salary1=model.predict(new_experience1)

print("predicted salary for 7 years is: ",predicted_salary)
print("predicted salary for 10 years is : ",predicted_salary1)

plt.scatter(df['salary'],df['experience'])
plt.plot(df['salary'],df['experience'],color='pink')
plt.xlabel('salary',color='purple')
plt.ylabel('experience',color='green')
plt.title('Linear Regression',color='orange')
plt.show()
# Out:
# predicted salary for 7 years is:  [55000.]
# predicted salary for 10 years is :  [70000.]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# predicted salary for 7 years is:  [55000.]
# predicted salary for 10 years is :  [70000.]
