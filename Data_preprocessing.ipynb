# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshita1204/python/blob/main/Data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# data preprocessing
import numpy as np
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-89d298bd-ff96-4434-bd11-a5860631a66c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-89d298bd-ff96-4434-bd11-a5860631a66c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# in dictionary, concept of keys values:Key: A unique identifier for a value. Keys must be immutable (e.g., strings, numbers, tuples).
# Value: The data associated with a key. Values can be of any data type and can be duplicated.
for key, value in uploaded.items():
   print('user uploaded files "{name}" with length {length} bytes'.format(name=key, length=len(value)))
# Out:
# user uploaded files "child_labour.xlsx" with length 8292 bytes

# %%
import io
data = pd.read_excel(io.BytesIO(uploaded['child_labour.xlsx']))
data.head()
# Out:
#       state  age  salary married
# 0   haryana    4     NaN     yes
# 1   haryana    5   687.0     yes
# 2  himachal    5   500.0      no
# 3     assam    5   400.0     no
# 4       NaN    6   876.0      no

# %%
x = data.iloc[:, :-1].values
xx = data.iloc[:, 1:3].values
print(x)
print(xx)
# Out:
# [['haryana' 4 nan]
#  ['haryana' 5 687.0]
#  ['himachal' 5 500.0]
#  ['assam' 5 400.0]
#  [nan 6 876.0]
#  ['punjab' 9 700.0]]
# [[  4.  nan]
#  [  5. 687.]
#  [  5. 500.]
#  [  5. 400.]
#  [  6. 876.]
#  [  9. 700.]]

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imputer= SimpleImputer(missing_values=np.nan,strategy='mean')
imputer= imputer.fit(x[:,1:3])
x[:,1:3]=imputer.transform(x[:,1:3])
print(x)

imputer = SimpleImputer(missing_values=np.nan , strategy = 'median')
imputer = imputer.fit(xx[:,1:3])
xx[:,1:3] = imputer.transform(xx[:,1:3])
print(xx)
# Out:
# [['haryana' 4.0 632.6]
#  ['haryana' 5.0 687.0]
#  ['himachal' 5.0 500.0]
#  ['assam' 5.0 400.0]
#  [nan 6.0 876.0]
#  ['punjab' 9.0 700.0]]
# [[  4. 687.]
#  [  5. 687.]
#  [  5. 500.]
#  [  5. 400.]
#  [  6. 876.]
#  [  9. 700.]]

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder_x=LabelEncoder()
x[:,0]=labelencoder_x.fit_transform(x[:,0])
print(x)
# Out:
# [[1 4.0 632.6]
#  [1 5.0 687.0]
#  [2 5.0 500.0]
#  [0 5.0 400.0]
#  [4 6.0 876.0]
#  [3 9.0 700.0]]
